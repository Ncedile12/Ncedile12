# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\BICT321 PROJECT\Books1.csv")
df = df.set_index('Book')
df
# Out:
#                                                          Author(s)  \
# Book
# A Tale of Two Cities                               Charles Dickens
# The Little Prince (Le Petit Prince)       Antoine de Saint-Exupéry
# The Alchemist (O Alquimista)                          Paulo Coelho
# Harry Potter and the Philosopher's Stone             J. K. Rowling
# And Then There Were None                           Agatha Christie
# Dream of the Red Chamber (紅樓夢)                          Cao Xueqin
# The Hobbit                                        J. R. R. Tolkien
#
#                                          Original language  First published  \
# Book
# A Tale of Two Cities                               English             1859
# The Little Prince (Le Petit Prince)                 French             1943
# The Alchemist (O Alquimista)                    Portuguese             1988
# Harry Potter and the Philosopher's Stone           English             1997
# And Then There Were None                           English             1939
# Dream of the Red Chamber (紅樓夢)                     Chinese             1791
# The Hobbit                                         English             1937
#
#                                                 Approximate sales  \
# Book
# A Tale of Two Cities                             >200 million[20]
# The Little Prince (Le Petit Prince)       200 million[21][22][23]
# The Alchemist (O Alquimista)                  150 million[24][25]
# Harry Potter and the Philosopher's Stone      120 million[26][27]
# And Then There Were None                          100 million[28]
# Dream of the Red Chamber (紅樓夢)                100 million[29][30]
# The Hobbit                                100 million[31][32][33]
#
#                                                                 Genre
# Book
# A Tale of Two Cities                               Historical fiction
# The Little Prince (Le Petit Prince)       Fantasy, children's fiction
# The Alchemist (O Alquimista)                                  Fantasy
# Harry Potter and the Philosopher's Stone  Fantasy, children's fiction
# And Then There Were None                                      Mystery
# Dream of the Red Chamber (紅樓夢)                            Family saga
# The Hobbit                                Fantasy, children's fiction

# %%
print(plt.style.available)
plt.style.use('classic')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
df.plot(kind = 'line', title = 'Best Selling Books', xlabel = 'Book', ylabel = 'Approximate Sales')
# Out:
# <Axes: title={'center': 'Best Selling Books'}, xlabel='Book', ylabel='Approximate Sales'>
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 32005 (\N{CJK UNIFIED IDEOGRAPH-7D05}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 27155 (\N{CJK UNIFIED IDEOGRAPH-6A13}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 22818 (\N{CJK UNIFIED IDEOGRAPH-5922}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 32005 (\N{CJK UNIFIED IDEOGRAPH-7D05}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 27155 (\N{CJK UNIFIED IDEOGRAPH-6A13}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22818 (\N{CJK UNIFIED IDEOGRAPH-5922}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.plot.barh(stacked = True)
# Out:
# <Axes: ylabel='Book'>
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 32005 (\N{CJK UNIFIED IDEOGRAPH-7D05}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 27155 (\N{CJK UNIFIED IDEOGRAPH-6A13}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 22818 (\N{CJK UNIFIED IDEOGRAPH-5922}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 32005 (\N{CJK UNIFIED IDEOGRAPH-7D05}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 27155 (\N{CJK UNIFIED IDEOGRAPH-6A13}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22818 (\N{CJK UNIFIED IDEOGRAPH-5922}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.plot.hist(bins = 50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot.area(figsize = (10,5))
# Out:
# <Axes: xlabel='Book'>
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 32005 (\N{CJK UNIFIED IDEOGRAPH-7D05}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 27155 (\N{CJK UNIFIED IDEOGRAPH-6A13}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 22818 (\N{CJK UNIFIED IDEOGRAPH-5922}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 32005 (\N{CJK UNIFIED IDEOGRAPH-7D05}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 27155 (\N{CJK UNIFIED IDEOGRAPH-6A13}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\222250089\AppData\Local\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22818 (\N{CJK UNIFIED IDEOGRAPH-5922}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
